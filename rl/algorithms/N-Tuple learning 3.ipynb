# %% [markdown]
# # N-Tuple Learning 3
#
# Created 2025-07-21

# %%
import numpy as np
import sys
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MaxNLocator
import ipywidgets as widgets
from ipyevents import Event
import time
import gymnasium as gym
import torch
import torch.nn as nn
from typing import Any, cast
from collections import deque
import random
import cv2
from IPython.display import HTML
from matplotlib.patches import FancyArrow

# %%
sys.path.insert(1, str(Path("../..")))
from andreas2048.game import *
from andreas2048 import gym2048
env = gym2048.Env2048()

# %%
raise RuntimeError("STOP")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raise RuntimeError("STOP")
#
# RuntimeError: STOP

# %% [markdown]
# ### 1: DQN with n-Tuple networks revisited

# %%
print(env.game)
# Out:
# <2048 Game: score: 588 - moves: 79 - highest tile: 64>
# [[ 0  2  2  8]
#  [ 0  4 16  2]
#  [ 2  8 64  4]
#  [ 0  8 32 16]]

# %%
class DQN(nn.Module):
    """ DQN implementation for a 2048 grid """

    def __init__(self, grid_shape: tuple[int, int], device: str) -> None:
        super().__init__()
        self.device = device
        assert grid_shape == (4,4)
        self.n_features = 14
        #self.powers = np.array([18**3, 18**2, 18, 1]).reshape(1,1,1,4)

        self.conv1 = nn.Conv3d(in_channels=self.n_features, out_channels=self.n_features, kernel_size=(1,1,2))
        self.conv2 = nn.Conv3d(in_channels=self.n_features, out_channels=self.n_features, kernel_size=(1,1,4))
        self.conv3 = nn.Conv3d(in_channels=self.n_features, out_channels=self.n_features, kernel_size=(1,1,4))
        self.conv4 = nn.Conv2d(in_channels=self.n_features, out_channels=self.n_features, kernel_size=(1,3))

        self.net = nn.Sequential(
            nn.Flatten(), # (n, 14, 4) -> (n, 56)
            nn.Linear(in_features=self.n_features*4, out_features=32),
            nn.Sigmoid(),
            nn.Linear(in_features=32, out_features=8),
            nn.Linear(in_features=8, out_features=1),
        )

        self.net.to(self.device)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """ Expects tensor of shape (n,14,4,3,4) """
        c1 = self.conv1.forward(x) # (n,14,4,3,4) -> (n,14,4,3,3)
        c2 = self.conv2.forward(x) # (n,14,4,3,4) -> (n,14,4,3,1)
        x = torch.cat([c1,c2], dim=-1) # (n,14,4,3,1) -> (n,14,4,3,4)
        x = self.conv3.forward(x).squeeze(-1) # (n,14,4,3,4) -> (n,14,4,3,1) -> (n,14,4,3)
        x = self.conv4.forward(x).squeeze(-1) # (n,14,4,3) -> (n,14,4,1) -> (n,14,4)
        x = torch.sigmoid(x)

        return self.net.forward(x)
    
    def V(self, x: np.ndarray, output_tensor: bool = False) -> np.ndarray|torch.Tensor:
        """ 
        Outputs the value function estimation by the model

        Args:
            x (np.ndarray): n-boards of shape (n,4,4) 

        Returns:
            V (np.ndarray): The value of the n-boards encoded as numpy array with shape (n,)
        
        """
        while len(x.shape) < 3: # (4,4) -> (1,4,4)
            x = x[None, ...]
        x = self.extract_tuples(x) # (n,4,4) -> (n,14,4,3,4)
        t = torch.from_numpy(x).float().to(self.device)
        #with torch.no_grad():
        vs = self.forward(t)
        vs = vs.squeeze(dim=-1)
        if output_tensor:
            return vs
        return vs.detach().numpy()
    

    def extract_tuples(self, grid: np.ndarray) -> np.ndarray:
        """
        Extract the n-tuples from n boards of shape (n, 4, 4). Returns the tuples as a numpy array of shape \n
        (n, |n_tuple|, 4, 4, 3) = (n, 14, 4, 3, 4) \n
        with the third value representing the rotation (Top, Right, Bottom, Left). The fourth values represents
        the current n-Tuple (index 0), the tuple prediction to the right (index 1) and left (index 2).
        The last values the ith value inside the n-tuple.
        """
        assert len(grid.shape) >= 3 and grid.shape[1] == 4 and grid.shape[2] == 4
        n_tuples = np.zeros(shape=(grid.shape[0],self.n_features,4,3,4), dtype=np.int8)
        for k in range(4):
            g_v = np.rot90(grid, k=k, axes=(1,2))
            n_tuples[:,0,k,0] = g_v[:,0,::-1] # Outer
            n_tuples[:,1,k,0] = g_v[:,1,:: 1] # Inner
            n_tuples[:,2,k,0] = g_v[:, [1,1,0,0], [-2,-1,-1,-2]] # Edge
            n_tuples[:,3,k,0] = g_v[:, [1,1,0,0], [-3,-2,-2,-3]] # Inner Edge
            n_tuples[:,4,k,0] = g_v[:, [2,1,1,0], [0,0,1,1]] # Left Z
            n_tuples[:,5,k,0] = g_v[:, [2,1,1,0], [1,1,2,2]] # Middle Z
            n_tuples[:,6,k,0] = g_v[:, [2,1,1,0], [2,2,3,3]] # Right Z
            n_tuples[:,7,k,0] = g_v[:, [2,1,1,0], [1,1,0,0]] # Left Mirror Z
            n_tuples[:,8,k,0] = g_v[:, [2,1,1,0], [2,2,1,1]] # Middle Mirror Z
            n_tuples[:,9,k,0] = g_v[:, [2,1,1,0], [3,3,2,2]] # Right Mirror Z
            n_tuples[:,10,k,0] = g_v[:, [2,1,0,0], [1,1,1,0]] # Left Arrow
            n_tuples[:,11,k,0] = g_v[:, [2,1,0,0], [2,2,2,1]] # Middle Arrow
            n_tuples[:,12,k,0] = g_v[:, [2,1,0,0], [3,3,3,2]] # Right Arrow
            n_tuples[:,13,k,0] = g_v[:, [1,0,0,0], [2,2,1,0]] # Edge Arrow
        
        n_tuples[:, :, :, 1] = State.table_cache[(4,4)][n_tuples[:,:,:,0,0], n_tuples[:,:,:,0,1], n_tuples[:,:,:,0,2], n_tuples[:,:,:,0,3]]
        n_tuples[:, :, :, 2] = State.table_cache[(4,4)][n_tuples[:,:,:,0,3], n_tuples[:,:,:,0,2], n_tuples[:,:,:,0,1], n_tuples[:,:,:,0,0]]
        #n_tuples[:, :, :, :4] = np.diff(n_tuples[:,:,:,:4], axis=-1, prepend=0)
        #n_tuples[:, :, :, :4] = np.diff(n_tuples[:,:,:,:4], axis=-1, prepend=0)
        return n_tuples
    
# Testing the implementation
net = DQN(grid_shape=env.game.shape, device="cpu")
print(net.extract_tuples(env.game.grid[None, :]).shape)
net.V(env.game.grid)
# Out:
# (1, 14, 4, 3, 4)
# array([0.38039225], dtype=float32)

# %%
class DQNAgent:
    """ Implements a simple DQN agent """
    
    def __init__( self,
                env: gym2048.Env2048, 
                learning_rate: float = 0.05, 
                gamma: float = 0.99,
                epsilon: float = 1.0,
                epsilon_decay = 0.005,
                epsilon_min = 0.001,
               ) -> None:
        self.env = env
        self.device = "cpu" #torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = DQN(grid_shape=env.game.grid.shape, device=self.device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=learning_rate)
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.gamma = gamma
        self.history: list[Game] = []

        self.replay_buffer: deque[tuple[State, int]] = deque(maxlen=10_000)
        self.batch_size: int = 200
        self._loss = 0

    def reset(self) -> None:
        if env.game.alive == False:
            #self.replay_buffer.extend([(s.clone(rot=k), env.game.score) for s in env.game.history for k in range(4)])
            self.replay_buffer.extend([(s, env.game.score) for s in env.game.history])
        env.reset()
        self.history.append(env.game)

    def update(self, game: Game, mode: Literal["Batch", "Last"] = "Last") -> None:
        match mode:
            case "Batch":
                if len(self.replay_buffer) < self.batch_size:
                    return
                #weights = np.log2([s.highest_tile for s, score in self.replay_buffer])
                batch = random.choices(self.replay_buffer, k=self.batch_size)
                states, scores = cast(tuple[list[State], list[int]], zip(*batch))

                grids = np.array([s.grid for s in states])
                scores = np.array([score for score in scores])
                scores = torch.from_numpy(scores).float().to(self.device)
            case "Last":
                grids = np.array([s.grid for s in game.history])
                scores = np.array([game.score for i in range(len(game.history))])
                scores = torch.from_numpy(scores).float().to(self.device)

        #weight_fn = lambda score: 0.2 + 0.8/(1+np.exp(-(np.log(score+1)-self.model.weight_mean)/self.model.weight_width))
        #weights = np.array([weight_fn(s.score) for s in game.history])
        #weights = torch.from_numpy(weights).float().to(self.device)

        vs = cast(torch.Tensor, self.model.V(grids, output_tensor=True))
        loss: torch.Tensor = nn.MSELoss()(vs, scores)
        self._loss = loss.detach().numpy()
        #loss = ((vs - scores) ** 2).mean()
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def step(self) -> bool:   
        next_state, reward, done, truncated, info = env.step(self.predict())
        return not(done or truncated)
    
    def predict(self) -> Action:
        possible_moves = self.env.game.get_moves()
        mask = np.array([(1 if a in possible_moves else 0) for a in Action])
        if np.random.rand() < self.epsilon:
            return self.env.action_space.sample(mask=mask)
        actions = self.get_qv()
        return max(actions, key=actions.get)
    
    def get_qv(self) -> dict[Action, float]:
        qvs = {}
        for a in Action:
            next_states = self.env.game.state.get_next_states(a)
            if len(next_states) == 1:
                continue
            next_states_grid = np.array([s.grid for s in next_states.keys()])
            v = self.model.V(next_states_grid)
            qvs[a] = np.sum([p*v for p, v in zip(next_states.values(), v)])
        return qvs
    
    @property
    def scores(self) -> list[float]:
        return [g.score for g in self.history]
    
    @property
    def highest_tiles(self) -> list[int]:
        return [g.highest_tile for g in self.history]
    
    @property
    def move_counts(self) -> list[int]:
        return [g.move_count for g in self.history] 
    
    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * (1 - self.epsilon_decay))


    def adjust_training_weights(self) -> None:
        pass
        #self.model.weight_mean = np.log(max(100, np.mean(self.scores[-500:])))
        #self.model.weight_width = 2


env = gym2048.Env2048(shape=(4,4))
agent = DQNAgent(env=env, gamma=0.99, learning_rate=0.001, epsilon=0.2, epsilon_decay=0.001, epsilon_min=0.05)
episode = -1

# %%
episode += 1
episode_cap = 10_000
try:
    for episode in range(episode, episode_cap):
        agent.reset()

        while env.game.alive:
            done = agent.step()
        agent.update(env.game, mode="Batch")
        agent.decay_epsilon()
        #agent.adjust_training_weights()

        s = f"Episode {episode:>4}/{episode_cap}"
        for v in [
            f"Score: {env.game.score:5}", 
            f"Highest tile: {env.game.highest_tile:4}",
            f"Length: {env.game.move_count:3}",
            f"Epsilon: {agent.epsilon:1.3f}",
            f"Average rolling score: {np.mean(agent.scores[max(0,episode-50):]):1.3f}",
            f"√Loss: {np.sqrt(agent._loss):7.1f}",
        ]:
            s += f" - {v}"
        print(s)

except KeyboardInterrupt:
    pass

ax1 = plt.subplot()
ax2 = ax1.twinx()
p1 = ax1.plot(np.log2(agent.highest_tiles), label="Highest tile", c="orange")
scores = agent.scores
p2 = ax2.plot([np.mean(scores[max(0,i-50):i]) for i in range(1,len(scores)+1)], label="Scores")
ax1.set_xlabel("Episode")
ax1.set_ylabel("Highest tile")
ax2.set_ylabel("Score")
ax1.yaxis.label.set_color(p1[0].get_color())
ax2.yaxis.label.set_color(p2[0].get_color())
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, pos: f"{2**x:n}"))
ax1.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.show()
# Out:
# Episode  443/10000 - Score:  1492 - Highest tile:  128 - Length: 148 - Epsilon: 0.129 - Average rolling score: 798.353 - √Loss:   960.7
# Episode  444/10000 - Score:  1640 - Highest tile:  128 - Length: 169 - Epsilon: 0.128 - Average rolling score: 822.745 - √Loss:   967.4
# Episode  445/10000 - Score:  3092 - Highest tile:  256 - Length: 253 - Epsilon: 0.128 - Average rolling score: 871.373 - √Loss:  1048.6
# Episode  446/10000 - Score:   348 - Highest tile:   32 - Length:  64 - Epsilon: 0.128 - Average rolling score: 871.294 - √Loss:  1033.1
# Episode  447/10000 - Score:   292 - Highest tile:   32 - Length:  54 - Epsilon: 0.128 - Average rolling score: 868.941 - √Loss:  1118.2
# Episode  448/10000 - Score:   540 - Highest tile:   64 - Length:  74 - Epsilon: 0.128 - Average rolling score: 873.961 - √Loss:  1051.3
# Episode  449/10000 - Score:  1088 - Highest tile:  128 - Length: 118 - Epsilon: 0.128 - Average rolling score: 871.843 - √Loss:  1096.9
# Episode  450/10000 - Score:   676 - Highest tile:   64 - Length:  93 - Epsilon: 0.128 - Average rolling score: 859.294 - √Loss:  1013.6
# Episode  451/10000 - Score:   904 - Highest tile:   64 - Length: 109 - Epsilon: 0.127 - Average rolling score: 858.431 - √Loss:  1078.1
# Episode  452/10000 - Score:   540 - Highest tile:   64 - Length:  75 - Epsilon: 0.127 - Average rolling score: 849.255 - √Loss:  1057.5
# Episode  453/10000 - Score:   476 - Highest tile:   64 - Length:  70 - Epsilon: 0.127 - Average rolling score: 852.000 - √Loss:  1036.1
# Episode  454/10000 - Score:   228 - Highest tile:   32 - Length:  46 - Epsilon: 0.127 - Average rolling score: 829.176 - √Loss:  1034.1
# Episode  455/10000 - Score:  1892 - Highest tile:  128 - Length: 183 - Epsilon: 0.127 - Average rolling score: 849.725 - √Loss:  1063.1
# Episode  456/10000 - Score:  1504 - Highest tile:  128 - Length: 151 - Epsilon: 0.127 - Average rolling score: 858.824 - √Loss:  1060.5
# Episode  457/10000 - Score:   612 - Highest tile:   64 - Length:  85 - Epsilon: 0.127 - Average rolling score: 859.294 - √Loss:  1186.3
# Episode  458/10000 - Score:  1312 - Highest tile:  128 - Length: 143 - Epsilon: 0.127 - Average rolling score: 866.667 - √Loss:  1071.4
# Episode  459/10000 - Score:  1216 - Highest tile:  128 - Length: 132 - Epsilon: 0.126 - Average rolling score: 864.863 - √Loss:  1087.7
# Episode  460/10000 - Score:  1584 - Highest tile:  128 - Length: 160 - Epsilon: 0.126 - Average rolling score: 881.176 - √Loss:   958.8
# Episode  461/10000 - Score:   488 - Highest tile:   64 - Length:  71 - Epsilon: 0.126 - Average rolling score: 868.392 - √Loss:  1101.2
# Episode  462/10000 - Score:  2476 - Highest tile:  256 - Length: 215 - Epsilon: 0.126 - Average rolling score: 901.490 - √Loss:  1046.8
# Episode  463/10000 - Score:   636 - Highest tile:   64 - Length:  86 - Epsilon: 0.126 - Average rolling score: 886.980 - √Loss:  1098.5
# Episode  464/10000 - Score:   580 - Highest tile:   64 - Length:  79 - Epsilon: 0.126 - Average rolling score: 876.784 - √Loss:  1063.7
# Episode  465/10000 - Score:  1332 - Highest tile:  128 - Length: 139 - Epsilon: 0.126 - Average rolling score: 885.176 - √Loss:   994.2
# Episode  466/10000 - Score:  1500 - Highest tile:  128 - Length: 156 - Epsilon: 0.126 - Average rolling score: 902.588 - √Loss:  1071.6
# Episode  467/10000 - Score:   728 - Highest tile:   64 - Length:  99 - Epsilon: 0.125 - Average rolling score: 904.392 - √Loss:   988.5
# Episode  468/10000 - Score:  1420 - Highest tile:  128 - Length: 149 - Epsilon: 0.125 - Average rolling score: 920.078 - √Loss:  1148.2
# Episode  469/10000 - Score:  1748 - Highest tile:  128 - Length: 177 - Epsilon: 0.125 - Average rolling score: 942.275 - √Loss:  1164.0
# Episode  470/10000 - Score:  1572 - Highest tile:  128 - Length: 156 - Epsilon: 0.125 - Average rolling score: 960.706 - √Loss:  1151.5
# Episode  471/10000 - Score:   676 - Highest tile:   64 - Length:  88 - Epsilon: 0.125 - Average rolling score: 958.275 - √Loss:  1142.6
# Episode  472/10000 - Score:   280 - Highest tile:   32 - Length:  53 - Epsilon: 0.125 - Average rolling score: 948.706 - √Loss:  1073.5
# Episode  473/10000 - Score:  1124 - Highest tile:  128 - Length: 126 - Epsilon: 0.125 - Average rolling score: 962.667 - √Loss:  1235.7
# Episode  474/10000 - Score:  2280 - Highest tile:  128 - Length: 214 - Epsilon: 0.125 - Average rolling score: 978.745 - √Loss:  1203.6
# Episode  475/10000 - Score:   396 - Highest tile:   32 - Length:  66 - Epsilon: 0.124 - Average rolling score: 985.176 - √Loss:  1161.2
# Episode  476/10000 - Score:  1036 - Highest tile:   64 - Length: 123 - Epsilon: 0.124 - Average rolling score: 999.843 - √Loss:  1117.8
# Episode  477/10000 - Score:   500 - Highest tile:   32 - Length:  79 - Epsilon: 0.124 - Average rolling score: 1004.706 - √Loss:  1073.3
# Episode  478/10000 - Score:  2252 - Highest tile:  256 - Length: 192 - Epsilon: 0.124 - Average rolling score: 1018.275 - √Loss:  1136.0
# Episode  479/10000 - Score:  1136 - Highest tile:  128 - Length: 125 - Epsilon: 0.124 - Average rolling score: 1026.118 - √Loss:  1206.9
# Episode  480/10000 - Score:   340 - Highest tile:   32 - Length:  63 - Epsilon: 0.124 - Average rolling score: 1026.980 - √Loss:  1097.7
# Episode  481/10000 - Score:  1376 - Highest tile:  128 - Length: 144 - Epsilon: 0.124 - Average rolling score: 1031.451 - √Loss:  1239.9
# Episode  482/10000 - Score:  1324 - Highest tile:  128 - Length: 147 - Epsilon: 0.124 - Average rolling score: 1053.882 - √Loss:  1233.6
# Episode  483/10000 - Score:  1148 - Highest tile:  128 - Length: 124 - Epsilon: 0.123 - Average rolling score: 1044.784 - √Loss:  1167.8
# Episode  484/10000 - Score:   416 - Highest tile:   32 - Length:  70 - Epsilon: 0.123 - Average rolling score: 1045.490 - √Loss:  1192.1
# Episode  485/10000 - Score:  1136 - Highest tile:   64 - Length: 128 - Epsilon: 0.123 - Average rolling score: 1060.549 - √Loss:  1102.3
# Episode  486/10000 - Score:  1136 - Highest tile:  128 - Length: 121 - Epsilon: 0.123 - Average rolling score: 1069.098 - √Loss:  1058.7
# Episode  487/10000 - Score:   348 - Highest tile:   32 - Length:  58 - Epsilon: 0.123 - Average rolling score: 1052.941 - √Loss:  1249.2
# Episode  488/10000 - Score:   584 - Highest tile:   64 - Length:  80 - Epsilon: 0.123 - Average rolling score: 1050.510 - √Loss:  1146.3
# Episode  489/10000 - Score:  1604 - Highest tile:  128 - Length: 162 - Epsilon: 0.123 - Average rolling score: 1070.588 - √Loss:  1203.4
# Episode  490/10000 - Score:  1388 - Highest tile:  128 - Length: 147 - Epsilon: 0.123 - Average rolling score: 1085.647 - √Loss:  1123.7
# Episode  491/10000 - Score:   680 - Highest tile:   64 - Length:  88 - Epsilon: 0.122 - Average rolling score: 1079.373 - √Loss:  1098.3
# Episode  492/10000 - Score:   840 - Highest tile:   64 - Length: 107 - Epsilon: 0.122 - Average rolling score: 1083.059 - √Loss:  1180.5
# Episode  493/10000 - Score:   692 - Highest tile:   64 - Length:  95 - Epsilon: 0.122 - Average rolling score: 1070.745 - √Loss:  1172.5
# Episode  494/10000 - Score:   400 - Highest tile:   32 - Length:  67 - Epsilon: 0.122 - Average rolling score: 1049.333 - √Loss:  1211.6
# Episode  495/10000 - Score:   372 - Highest tile:   32 - Length:  65 - Epsilon: 0.122 - Average rolling score: 1024.471 - √Loss:  1158.7
# Episode  496/10000 - Score:   628 - Highest tile:   64 - Length:  87 - Epsilon: 0.122 - Average rolling score: 976.157 - √Loss:  1106.0
# Episode  497/10000 - Score:   564 - Highest tile:   64 - Length:  82 - Epsilon: 0.122 - Average rolling score: 980.392 - √Loss:  1246.6
# Episode  498/10000 - Score:  1352 - Highest tile:  128 - Length: 143 - Epsilon: 0.122 - Average rolling score: 1001.176 - √Loss:  1141.2
# Episode  499/10000 - Score:  1032 - Highest tile:  128 - Length: 111 - Epsilon: 0.122 - Average rolling score: 1010.824 - √Loss:  1125.3
# Episode  500/10000 - Score:   420 - Highest tile:   32 - Length:  67 - Epsilon: 0.121 - Average rolling score: 997.725 - √Loss:  1045.4
# Episode  501/10000 - Score:   380 - Highest tile:   32 - Length:  64 - Epsilon: 0.121 - Average rolling score: 991.922 - √Loss:  1303.6
# Episode  502/10000 - Score:   400 - Highest tile:   32 - Length:  66 - Epsilon: 0.121 - Average rolling score: 982.039 - √Loss:  1117.5
# Episode  503/10000 - Score:   560 - Highest tile:   64 - Length:  76 - Epsilon: 0.121 - Average rolling score: 982.431 - √Loss:  1207.8
# Episode  504/10000 - Score:  1408 - Highest tile:  128 - Length: 149 - Epsilon: 0.121 - Average rolling score: 1000.706 - √Loss:  1200.9
# Episode  505/10000 - Score:  1660 - Highest tile:  128 - Length: 165 - Epsilon: 0.121 - Average rolling score: 1028.784 - √Loss:  1114.8
# Episode  506/10000 - Score:  2200 - Highest tile:  256 - Length: 191 - Epsilon: 0.121 - Average rolling score: 1034.824 - √Loss:  1152.2
# Episode  507/10000 - Score:  1264 - Highest tile:  128 - Length: 128 - Epsilon: 0.121 - Average rolling score: 1030.118 - √Loss:  1072.2
# Episode  508/10000 - Score:  1456 - Highest tile:  128 - Length: 153 - Epsilon: 0.120 - Average rolling score: 1046.667 - √Loss:  1279.9
# Episode  509/10000 - Score:  1228 - Highest tile:  128 - Length: 136 - Epsilon: 0.120 - Average rolling score: 1045.020 - √Loss:  1192.1
# Episode  510/10000 - Score:   884 - Highest tile:   64 - Length: 106 - Epsilon: 0.120 - Average rolling score: 1038.510 - √Loss:  1165.8
# Episode  511/10000 - Score:   536 - Highest tile:   64 - Length:  73 - Epsilon: 0.120 - Average rolling score: 1017.961 - √Loss:  1174.7
# Episode  512/10000 - Score:  1044 - Highest tile:  128 - Length: 115 - Epsilon: 0.120 - Average rolling score: 1028.863 - √Loss:  1216.7
# Episode  513/10000 - Score:  1324 - Highest tile:  128 - Length: 137 - Epsilon: 0.120 - Average rolling score: 1006.275 - √Loss:  1149.7
# Episode  514/10000 - Score:  1304 - Highest tile:  128 - Length: 133 - Epsilon: 0.120 - Average rolling score: 1019.373 - √Loss:  1207.2
# Episode  515/10000 - Score:   300 - Highest tile:   32 - Length:  55 - Epsilon: 0.120 - Average rolling score: 1013.882 - √Loss:  1234.8
# Episode  516/10000 - Score:   372 - Highest tile:   32 - Length:  67 - Epsilon: 0.119 - Average rolling score: 995.059 - √Loss:  1225.5
# Episode  517/10000 - Score:   876 - Highest tile:   64 - Length: 115 - Epsilon: 0.119 - Average rolling score: 982.824 - √Loss:  1193.3
# Episode  518/10000 - Score:  1764 - Highest tile:  128 - Length: 181 - Epsilon: 0.119 - Average rolling score: 1003.137 - √Loss:  1242.3
# Episode  519/10000 - Score:  1976 - Highest tile:  256 - Length: 162 - Epsilon: 0.119 - Average rolling score: 1014.039 - √Loss:  1150.1
# Episode  520/10000 - Score:  1220 - Highest tile:  128 - Length: 127 - Epsilon: 0.119 - Average rolling score: 1003.686 - √Loss:  1187.4
# Episode  521/10000 - Score:   700 - Highest tile:   64 - Length:  89 - Epsilon: 0.119 - Average rolling score: 986.588 - √Loss:  1196.5
# Episode  522/10000 - Score:  1364 - Highest tile:  128 - Length: 143 - Epsilon: 0.119 - Average rolling score: 1000.078 - √Loss:  1165.4
# Episode  523/10000 - Score:  1176 - Highest tile:   64 - Length: 140 - Epsilon: 0.119 - Average rolling score: 1017.647 - √Loss:  1224.5
# Episode  524/10000 - Score:  1456 - Highest tile:  128 - Length: 143 - Epsilon: 0.119 - Average rolling score: 1024.157 - √Loss:  1233.4
# Episode  525/10000 - Score:   760 - Highest tile:   64 - Length: 102 - Epsilon: 0.118 - Average rolling score: 994.353 - √Loss:  1243.9
# Episode  526/10000 - Score:  1092 - Highest tile:  128 - Length: 118 - Epsilon: 0.118 - Average rolling score: 1008.000 - √Loss:  1228.9
# Episode  527/10000 - Score:   376 - Highest tile:   32 - Length:  62 - Epsilon: 0.118 - Average rolling score: 995.059 - √Loss:  1284.2
# Episode  528/10000 - Score:  1508 - Highest tile:  128 - Length: 161 - Epsilon: 0.118 - Average rolling score: 1014.824 - √Loss:  1183.7
# Episode  529/10000 - Score:   724 - Highest tile:   64 - Length:  96 - Epsilon: 0.118 - Average rolling score: 984.863 - √Loss:  1255.3
# Episode  530/10000 - Score:   672 - Highest tile:   64 - Length:  87 - Epsilon: 0.118 - Average rolling score: 975.765 - √Loss:  1299.2
# Episode  531/10000 - Score:  1528 - Highest tile:  128 - Length: 156 - Epsilon: 0.118 - Average rolling score: 999.059 - √Loss:  1263.6
# Episode  532/10000 - Score:  2164 - Highest tile:  256 - Length: 182 - Epsilon: 0.118 - Average rolling score: 1014.510 - √Loss:  1160.0
# Episode  533/10000 - Score:  1336 - Highest tile:  128 - Length: 135 - Epsilon: 0.117 - Average rolling score: 1014.745 - √Loss:  1132.2
# Episode  534/10000 - Score:  1696 - Highest tile:  128 - Length: 169 - Epsilon: 0.117 - Average rolling score: 1025.490 - √Loss:  1242.7
# Episode  535/10000 - Score:  1476 - Highest tile:  128 - Length: 153 - Epsilon: 0.117 - Average rolling score: 1046.275 - √Loss:  1130.8
# Episode  536/10000 - Score:  1060 - Highest tile:  128 - Length: 115 - Epsilon: 0.117 - Average rolling score: 1044.784 - √Loss:  1134.1
# Episode  537/10000 - Score:  2596 - Highest tile:  256 - Length: 219 - Epsilon: 0.117 - Average rolling score: 1073.412 - √Loss:  1252.9
# Episode  538/10000 - Score:   740 - Highest tile:   64 - Length:  99 - Epsilon: 0.117 - Average rolling score: 1081.098 - √Loss:  1199.5
# Episode  539/10000 - Score:  1420 - Highest tile:  128 - Length: 148 - Epsilon: 0.117 - Average rolling score: 1097.490 - √Loss:  1278.7
# Episode  540/10000 - Score:  1032 - Highest tile:   64 - Length: 124 - Epsilon: 0.117 - Average rolling score: 1086.275 - √Loss:  1236.3
# Episode  541/10000 - Score:   704 - Highest tile:   64 - Length:  90 - Epsilon: 0.117 - Average rolling score: 1072.863 - √Loss:  1228.6
# Episode  542/10000 - Score:   512 - Highest tile:   64 - Length:  75 - Epsilon: 0.116 - Average rolling score: 1069.569 - √Loss:  1120.6
# Episode  543/10000 - Score:   168 - Highest tile:   16 - Length:  42 - Epsilon: 0.116 - Average rolling score: 1056.392 - √Loss:  1245.1
# Episode  544/10000 - Score:  1760 - Highest tile:  128 - Length: 180 - Epsilon: 0.116 - Average rolling score: 1077.333 - √Loss:  1177.1
# Episode  545/10000 - Score:   692 - Highest tile:   64 - Length:  92 - Epsilon: 0.116 - Average rolling score: 1083.059 - √Loss:  1260.2
# Episode  546/10000 - Score:   460 - Highest tile:   32 - Length:  75 - Epsilon: 0.116 - Average rolling score: 1084.784 - √Loss:  1195.6
# Episode  547/10000 - Score:   924 - Highest tile:   64 - Length: 112 - Epsilon: 0.116 - Average rolling score: 1090.588 - √Loss:  1192.7
# Episode  548/10000 - Score:  1448 - Highest tile:  128 - Length: 151 - Epsilon: 0.116 - Average rolling score: 1107.922 - √Loss:  1180.2
# Episode  549/10000 - Score:   644 - Highest tile:   64 - Length:  89 - Epsilon: 0.116 - Average rolling score: 1094.039 - √Loss:  1219.3
# Episode  550/10000 - Score:  2208 - Highest tile:  256 - Length: 183 - Epsilon: 0.115 - Average rolling score: 1117.098 - √Loss:  1184.3
# Episode  551/10000 - Score:   696 - Highest tile:   64 - Length:  95 - Epsilon: 0.115 - Average rolling score: 1122.510 - √Loss:  1226.4
# Episode  552/10000 - Score:  1232 - Highest tile:  128 - Length: 127 - Epsilon: 0.115 - Average rolling score: 1139.216 - √Loss:  1257.1

# %%
HTML(agent.history[20].render_game(value_func=lambda x: f"V = {agent.model.V(x)[0]:1.3f}").to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgcb468183c06c4ef090a5eb35fd6368ad">
#   <div class="anim-controls">
#     <input id="_anim_slidercb468183c06c4ef090a5eb35fd6368ad" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animcb468183c06c4ef090a5eb35fd6368ad.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animcb468183c06c4ef090a5eb35fd6368ad.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animcb468183c06c4ef090a5eb35fd6368ad.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animcb468183c06c4ef090a5eb35fd6368ad.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animcb468183c06c4ef090a5eb35fd6368ad.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animcb468183c06c4ef090a5eb35fd6368ad.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animcb468183c06c4ef090a5eb35fd6368ad.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animcb468183c06c4ef090a5eb35fd6368ad.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animcb468183c06c4ef090a5eb35fd6368ad.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animcb468183c06c4ef090a5eb35fd6368ad.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectcb468183c06c4ef090a5eb35fd6368ad"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_cb468183c06c4ef090a5eb35fd6368ad"
#              checked>
#       <label for="_anim_radio1_cb468183c06c4ef090a5eb35fd6368ad">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_cb468183c06c4ef090a5eb35fd6368ad"
#              >
#       <label for="_anim_radio2_cb468183c06c4ef090a5eb35fd6368ad">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_cb468183c06c4ef090a5eb35fd6368ad"
#              >
#       <label for="_anim_radio3_cb468183c06c4ef090a5eb35fd6368ad">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgcb468183c06c4ef090a5eb35fd6368ad";
#     var slider_id = "_anim_slidercb468183c06c4ef090a5eb35fd6368ad";
#     var loop_select_id = "_anim_loop_selectcb468183c06c4ef090a5eb35fd6368ad";
#     var frames = new Array(121);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAVKZJ
